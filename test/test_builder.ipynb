# %%
import config
from src.cdm.contractDetailsBuilder import ContractDetailsBuilder

# %%
# Example usage:
connection_string = config.connection_string
collection_name = "fpml-documents"
builder = ContractDetailsBuilder(connection_string, collection_name)
contract_details_json = builder.buildContractDetails()
print(contract_details_json)
# Out:
# C:\Users\David\Documents\TradeHeader\RAG\.venv\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Starting process for enum class: MasterAgreementTypeEnum
# ...
#
# Processing description 1/35 for enum: AFB
# C:\Users\David\Documents\TradeHeader\RAG\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainPendingDeprecationWarning: This class is pending deprecation and may be removed in a future version. You can swap to using the `PGVector` implementation in `langchain_postgres`. Please read the guidelines in the doc-string of this class to follow prior to migrating as there are some differences between the implementations. See https://github.com/langchain-ai/langchain-postgres for details aboutthe new implementation.
#   warn_deprecated(
# ...
